# %%
import numpy as np

# %%
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[9.0,8.0,7.0],[6.0,5.0,4.0]])
print(b)
# Out:
# [[9. 8. 7.]
#  [6. 5. 4.]]

# %%
# get dimension
a.ndim
# Out:
# 2

# %%
# get dimension
b.ndim
# Out:
# 2

# %%
# get shape
a.shape
# Out:
# (3,)

# %%
# get shape
b.shape
# Out:
# (2, 3)

# %%
#get type
a.dtype
# Out:
# dtype('int64')

# %%
#get size
a.itemsize
# Out:
# 8

# %%
# get total size
a.nbytes
# Out:
# 24
